# %% [markdown]
# <a href="https://colab.research.google.com/github/RobotMa/lerobot/blob/dev%2Fqianli-yolo/experiment/training-smolvla.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🤗 x 🦾: Training SmolVLA with LeRobot Notebook
#
# Welcome to the **LeRobot SmolVLA training notebook**! This notebook provides a ready-to-run setup for training imitation learning policies using the [🤗 LeRobot](https://github.com/huggingface/lerobot) library.
#
# In this example, we train an `SmolVLA` policy using a dataset hosted on the [Hugging Face Hub](https://huggingface.co/), and optionally track training metrics with [Weights & Biases (wandb)](https://wandb.ai/).
#
# ## ⚙️ Requirements
# - A Hugging Face dataset repo ID containing your training data (`--dataset.repo_id=YOUR_USERNAME/YOUR_DATASET`)
# - Optional: A [wandb](https://wandb.ai/) account if you want to enable training visualization
# - Recommended: GPU runtime (e.g., NVIDIA A100) for faster training
#
# ## ⏱️ Expected Training Time
# Training with the `SmolVLA` policy for 20,000 steps typically takes **about 5 hours on an NVIDIA A100** GPU. On less powerful GPUs or CPUs, training may take significantly longer!
#
# ## Example Output
# Model checkpoints, logs, and training plots will be saved to the specified `--output_dir`. If `wandb` is enabled, progress will also be visualized in your wandb project dashboard.

# %% [markdown]
# ## Install conda
# This cell uses `condacolab` to bootstrap a full Conda environment inside Google Colab.

# %%
# !pip install -q condacolab
import condacolab
condacolab.install()
# Out:
# ✨🍰✨ Everything looks OK!

# %% [markdown]
# ## Install LeRobot
# This cell clones the `lerobot` repository from Hugging Face, installs FFmpeg (version 7.1.1), and installs the package in editable mode.

# %%
# !git clone https://github.com/huggingface/lerobot.git
# !conda install python=3.12 ffmpeg=7.1.1 -c conda-forge
# !cd lerobot && pip install -e .
# !pip install 'lerobot[training]'
# !pip install 'lerobot[dataset]'
# Out:
# fatal: destination path 'lerobot' already exists and is not an empty directory.
# Channels:
#  - conda-forge
# Platform: linux-64
# done
# done
#
# # All requested packages already installed.
#
# Obtaining file:///content/lerobot
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Requirement already satisfied: torch<2.12.0,>=2.7 in /usr/local/lib/python3.12/site-packages (from lerobot==0.5.2) (2.11.0)
# Requirement already satisfied: torchvision<0.27.0,>=0.22.0 in /usr/local/lib/python3.12/site-packages (from lerobot==0.5.2) (0.26.0)
# Requirement already satisfied: numpy<2.3.0,>=2.0.0 in /usr/local/lib/python3.12/site-packages (from lerobot==0.5.2) (2.2.6)
# Requirement already satisfied: opencv-python-headless<4.14.0,>=4.9.0 in /usr/local/lib/python3.12/site-packages (from lerobot==0.5.2) (4.13.0.92)
# Requirement already satisfied: Pillow<13.0.0,>=10.0.0 in /usr/local/lib/python3.12/site-packages (from lerobot==0.5.2) (12.2.0)
# Requirement already satisfied: einops<0.9.0,>=0.8.0 in /usr/local/lib/python3.12/site-packages (from lerobot==0.5.2) (0.8.2)
# Requirement already satisfied: draccus==0.10.0 in /usr/local/lib/python3.12/site-packages (from lerobot==0.5.2) (0.10.0)
# Requirement already satisfied: huggingface-hub<2.0.0,>=1.0.0 in /usr/local/lib/python3.12/site-packages (from lerobot==0.5.2) (1.15.0)
# Requirement already satisfied: requests<3.0.0,>=2.32.0 in /usr/local/lib/python3.12/site-packages (from lerobot==0.5.2) (2.32.3)
# Requirement already satisfied: gymnasium<2.0.0,>=1.1.1 in /usr/local/lib/python3.12/site-packages (from lerobot==0.5.2) (1.3.0)
# Requirement already satisfied: safetensors<1.0.0,>=0.4.3 in /usr/local/lib/python3.12/site-packages (from lerobot==0.5.2) (0.7.0)
# Requirement already satisfied: packaging<26.0,>=24.2 in /usr/local/lib/python3.12/site-packages (from lerobot==0.5.2) (24.2)
# Requirement already satisfied: termcolor<4.0.0,>=2.4.0 in /usr/local/lib/python3.12/site-packages (from lerobot==0.5.2) (3.3.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.0 in /usr/local/lib/python3.12/site-packages (from lerobot==0.5.2) (4.67.1)
# Requirement already satisfied: cmake<4.2.0,>=3.29.0.1 in /usr/local/lib/python3.12/site-packages (from lerobot==0.5.2) (4.1.3)
# Requirement already satisfied: setuptools<81.0.0,>=71.0.0 in /usr/local/lib/python3.12/site-packages (from lerobot==0.5.2) (80.10.2)
# Requirement already satisfied: mergedeep~=1.3 in /usr/local/lib/python3.12/site-packages (from draccus==0.10.0->lerobot==0.5.2) (1.3.4)
# Requirement already satisfied: pyyaml~=6.0 in /usr/local/lib/python3.12/site-packages (from draccus==0.10.0->lerobot==0.5.2) (6.0.3)
# Requirement already satisfied: pyyaml-include~=1.4 in /usr/local/lib/python3.12/site-packages (from draccus==0.10.0->lerobot==0.5.2) (1.4.1)
# Requirement already satisfied: toml~=0.10 in /usr/local/lib/python3.12/site-packages (from draccus==0.10.0->lerobot==0.5.2) (0.10.2)
# Requirement already satisfied: typing-inspect~=0.9.0 in /usr/local/lib/python3.12/site-packages (from draccus==0.10.0->lerobot==0.5.2) (0.9.0)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.12/site-packages (from gymnasium<2.0.0,>=1.1.1->lerobot==0.5.2) (3.1.2)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.12/site-packages (from gymnasium<2.0.0,>=1.1.1->lerobot==0.5.2) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.12/site-packages (from gymnasium<2.0.0,>=1.1.1->lerobot==0.5.2) (0.0.6)
# Requirement already satisfied: filelock>=3.10.0 in /usr/local/lib/python3.12/site-packages (from huggingface-hub<2.0.0,>=1.0.0->lerobot==0.5.2) (3.29.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/site-packages (from huggingface-hub<2.0.0,>=1.0.0->lerobot==0.5.2) (2026.2.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in /usr/local/lib/python3.12/site-packages (from huggingface-hub<2.0.0,>=1.0.0->lerobot==0.5.2) (1.5.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/site-packages (from huggingface-hub<2.0.0,>=1.0.0->lerobot==0.5.2) (0.28.1)
# Requirement already satisfied: typer>=0.20.0 in /usr/local/lib/python3.12/site-packages (from huggingface-hub<2.0.0,>=1.0.0->lerobot==0.5.2) (0.25.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/site-packages (from requests<3.0.0,>=2.32.0->lerobot==0.5.2) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/site-packages (from requests<3.0.0,>=2.32.0->lerobot==0.5.2) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/site-packages (from requests<3.0.0,>=2.32.0->lerobot==0.5.2) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/site-packages (from requests<3.0.0,>=2.32.0->lerobot==0.5.2) (2026.4.22)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/site-packages (from torch<2.12.0,>=2.7->lerobot==0.5.2) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/site-packages (from torch<2.12.0,>=2.7->lerobot==0.5.2) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/site-packages (from torch<2.12.0,>=2.7->lerobot==0.5.2) (3.1.6)
# Requirement already satisfied: cuda-toolkit==13.0.2 in /usr/local/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch<2.12.0,>=2.7->lerobot==0.5.2) (13.0.2)
# Requirement already satisfied: cuda-bindings<14,>=13.0.3 in /usr/local/lib/python3.12/site-packages (from torch<2.12.0,>=2.7->lerobot==0.5.2) (13.2.0)
# Requirement already satisfied: nvidia-cudnn-cu13==9.19.0.56 in /usr/local/lib/python3.12/site-packages (from torch<2.12.0,>=2.7->lerobot==0.5.2) (9.19.0.56)
# Requirement already satisfied: nvidia-cusparselt-cu13==0.8.0 in /usr/local/lib/python3.12/site-packages (from torch<2.12.0,>=2.7->lerobot==0.5.2) (0.8.0)
# Requirement already satisfied: nvidia-nccl-cu13==2.28.9 in /usr/local/lib/python3.12/site-packages (from torch<2.12.0,>=2.7->lerobot==0.5.2) (2.28.9)
# Requirement already satisfied: nvidia-nvshmem-cu13==3.4.5 in /usr/local/lib/python3.12/site-packages (from torch<2.12.0,>=2.7->lerobot==0.5.2) (3.4.5)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/site-packages (from torch<2.12.0,>=2.7->lerobot==0.5.2) (3.6.0)
# Requirement already satisfied: nvidia-cublas==13.1.0.3.* in /usr/local/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch<2.12.0,>=2.7->lerobot==0.5.2) (13.1.0.3)
# Requirement already satisfied: nvidia-cuda-runtime==13.0.96.* in /usr/local/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch<2.12.0,>=2.7->lerobot==0.5.2) (13.0.96)
# Requirement already satisfied: nvidia-cufft==12.0.0.61.* in /usr/local/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch<2.12.0,>=2.7->lerobot==0.5.2) (12.0.0.61)
# Requirement already satisfied: nvidia-cufile==1.15.1.6.* in /usr/local/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch<2.12.0,>=2.7->lerobot==0.5.2) (1.15.1.6)
# Requirement already satisfied: nvidia-cuda-cupti==13.0.85.* in /usr/local/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch<2.12.0,>=2.7->lerobot==0.5.2) (13.0.85)
# Requirement already satisfied: nvidia-curand==10.4.0.35.* in /usr/local/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch<2.12.0,>=2.7->lerobot==0.5.2) (10.4.0.35)
# Requirement already satisfied: nvidia-cusolver==12.0.4.66.* in /usr/local/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch<2.12.0,>=2.7->lerobot==0.5.2) (12.0.4.66)
# Requirement already satisfied: nvidia-cusparse==12.6.3.3.* in /usr/local/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch<2.12.0,>=2.7->lerobot==0.5.2) (12.6.3.3)
# Requirement already satisfied: nvidia-nvjitlink==13.0.88.* in /usr/local/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch<2.12.0,>=2.7->lerobot==0.5.2) (13.0.88)
# Requirement already satisfied: nvidia-cuda-nvrtc==13.0.88.* in /usr/local/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch<2.12.0,>=2.7->lerobot==0.5.2) (13.0.88)
# Requirement already satisfied: nvidia-nvtx==13.0.85.* in /usr/local/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch<2.12.0,>=2.7->lerobot==0.5.2) (13.0.85)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/site-packages (from cuda-bindings<14,>=13.0.3->torch<2.12.0,>=2.7->lerobot==0.5.2) (1.5.4)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0.0,>=1.0.0->lerobot==0.5.2) (4.13.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0.0,>=1.0.0->lerobot==0.5.2) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0.0,>=1.0.0->lerobot==0.5.2) (0.16.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/site-packages (from sympy>=1.13.3->torch<2.12.0,>=2.7->lerobot==0.5.2) (1.3.0)
# Requirement already satisfied: click>=8.2.1 in /usr/local/lib/python3.12/site-packages (from typer>=0.20.0->huggingface-hub<2.0.0,>=1.0.0->lerobot==0.5.2) (8.4.0)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/site-packages (from typer>=0.20.0->huggingface-hub<2.0.0,>=1.0.0->lerobot==0.5.2) (1.5.4)
# Requirement already satisfied: rich>=13.8.0 in /usr/local/lib/python3.12/site-packages (from typer>=0.20.0->huggingface-hub<2.0.0,>=1.0.0->lerobot==0.5.2) (15.0.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/site-packages (from typer>=0.20.0->huggingface-hub<2.0.0,>=1.0.0->lerobot==0.5.2) (0.0.4)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.12/site-packages (from typing-inspect~=0.9.0->draccus==0.10.0->lerobot==0.5.2) (1.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/site-packages (from jinja2->torch<2.12.0,>=2.7->lerobot==0.5.2) (3.0.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/site-packages (from rich>=13.8.0->typer>=0.20.0->huggingface-hub<2.0.0,>=1.0.0->lerobot==0.5.2) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/site-packages (from rich>=13.8.0->typer>=0.20.0->huggingface-hub<2.0.0,>=1.0.0->lerobot==0.5.2) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer>=0.20.0->huggingface-hub<2.0.0,>=1.0.0->lerobot==0.5.2) (0.1.2)
# Building wheels for collected packages: lerobot
#   Building editable for lerobot (pyproject.toml) ... done
#   Created wheel for lerobot: filename=lerobot-0.5.2-0.editable-py3-none-any.whl size=13549 sha256=237fa94f6a4f1b0568f4a51cd96ae54785463f7d6757bfdfd713d56909cb539d
#   Stored in directory: /tmp/pip-ephem-wheel-cache-9niuq_74/wheels/09/b4/fe/75732b1d640db96ba1f856f2b7328b232a03b696a39cb59686
# Successfully built lerobot
# Installing collected packages: lerobot
#   Attempting uninstall: lerobot
#     Found existing installation: lerobot 0.5.2
#     Uninstalling lerobot-0.5.2:
#       Successfully uninstalled lerobot-0.5.2
# Successfully installed lerobot-0.5.2
# Requirement already satisfied: lerobot[training] in /usr/local/lib/python3.12/site-packages (0.5.2)
# Requirement already satisfied: torch<2.12.0,>=2.7 in /usr/local/lib/python3.12/site-packages (from lerobot[training]) (2.11.0)
# Requirement already satisfied: torchvision<0.27.0,>=0.22.0 in /usr/local/lib/python3.12/site-packages (from lerobot[training]) (0.26.0)
# Requirement already satisfied: numpy<2.3.0,>=2.0.0 in /usr/local/lib/python3.12/site-packages (from lerobot[training]) (2.2.6)
# Requirement already satisfied: opencv-python-headless<4.14.0,>=4.9.0 in /usr/local/lib/python3.12/site-packages (from lerobot[training]) (4.13.0.92)
# Requirement already satisfied: Pillow<13.0.0,>=10.0.0 in /usr/local/lib/python3.12/site-packages (from lerobot[training]) (12.2.0)
# Requirement already satisfied: einops<0.9.0,>=0.8.0 in /usr/local/lib/python3.12/site-packages (from lerobot[training]) (0.8.2)
# Requirement already satisfied: draccus==0.10.0 in /usr/local/lib/python3.12/site-packages (from lerobot[training]) (0.10.0)
# Requirement already satisfied: huggingface-hub<2.0.0,>=1.0.0 in /usr/local/lib/python3.12/site-packages (from lerobot[training]) (1.15.0)
# Requirement already satisfied: requests<3.0.0,>=2.32.0 in /usr/local/lib/python3.12/site-packages (from lerobot[training]) (2.32.3)
# Requirement already satisfied: gymnasium<2.0.0,>=1.1.1 in /usr/local/lib/python3.12/site-packages (from lerobot[training]) (1.3.0)
# Requirement already satisfied: safetensors<1.0.0,>=0.4.3 in /usr/local/lib/python3.12/site-packages (from lerobot[training]) (0.7.0)
# Requirement already satisfied: packaging<26.0,>=24.2 in /usr/local/lib/python3.12/site-packages (from lerobot[training]) (24.2)
# Requirement already satisfied: termcolor<4.0.0,>=2.4.0 in /usr/local/lib/python3.12/site-packages (from lerobot[training]) (3.3.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.0 in /usr/local/lib/python3.12/site-packages (from lerobot[training]) (4.67.1)
# Requirement already satisfied: cmake<4.2.0,>=3.29.0.1 in /usr/local/lib/python3.12/site-packages (from lerobot[training]) (4.1.3)
# Requirement already satisfied: setuptools<81.0.0,>=71.0.0 in /usr/local/lib/python3.12/site-packages (from lerobot[training]) (80.10.2)
# Requirement already satisfied: accelerate<2.0.0,>=1.10.0 in /usr/local/lib/python3.12/site-packages (from lerobot[training]) (1.13.0)
# Requirement already satisfied: wandb<0.25.0,>=0.24.0 in /usr/local/lib/python3.12/site-packages (from lerobot[training]) (0.24.2)
# Requirement already satisfied: mergedeep~=1.3 in /usr/local/lib/python3.12/site-packages (from draccus==0.10.0->lerobot[training]) (1.3.4)
# Requirement already satisfied: pyyaml~=6.0 in /usr/local/lib/python3.12/site-packages (from draccus==0.10.0->lerobot[training]) (6.0.3)
# Requirement already satisfied: pyyaml-include~=1.4 in /usr/local/lib/python3.12/site-packages (from draccus==0.10.0->lerobot[training]) (1.4.1)
# Requirement already satisfied: toml~=0.10 in /usr/local/lib/python3.12/site-packages (from draccus==0.10.0->lerobot[training]) (0.10.2)
# Requirement already satisfied: typing-inspect~=0.9.0 in /usr/local/lib/python3.12/site-packages (from draccus==0.10.0->lerobot[training]) (0.9.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/site-packages (from accelerate<2.0.0,>=1.10.0->lerobot[training]) (7.2.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.12/site-packages (from gymnasium<2.0.0,>=1.1.1->lerobot[training]) (3.1.2)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.12/site-packages (from gymnasium<2.0.0,>=1.1.1->lerobot[training]) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.12/site-packages (from gymnasium<2.0.0,>=1.1.1->lerobot[training]) (0.0.6)
# Requirement already satisfied: filelock>=3.10.0 in /usr/local/lib/python3.12/site-packages (from huggingface-hub<2.0.0,>=1.0.0->lerobot[training]) (3.29.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/site-packages (from huggingface-hub<2.0.0,>=1.0.0->lerobot[training]) (2026.2.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in /usr/local/lib/python3.12/site-packages (from huggingface-hub<2.0.0,>=1.0.0->lerobot[training]) (1.5.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/site-packages (from huggingface-hub<2.0.0,>=1.0.0->lerobot[training]) (0.28.1)
# Requirement already satisfied: typer>=0.20.0 in /usr/local/lib/python3.12/site-packages (from huggingface-hub<2.0.0,>=1.0.0->lerobot[training]) (0.25.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/site-packages (from requests<3.0.0,>=2.32.0->lerobot[training]) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/site-packages (from requests<3.0.0,>=2.32.0->lerobot[training]) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/site-packages (from requests<3.0.0,>=2.32.0->lerobot[training]) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/site-packages (from requests<3.0.0,>=2.32.0->lerobot[training]) (2026.4.22)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/site-packages (from torch<2.12.0,>=2.7->lerobot[training]) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/site-packages (from torch<2.12.0,>=2.7->lerobot[training]) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/site-packages (from torch<2.12.0,>=2.7->lerobot[training]) (3.1.6)
# Requirement already satisfied: cuda-toolkit==13.0.2 in /usr/local/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch<2.12.0,>=2.7->lerobot[training]) (13.0.2)
# Requirement already satisfied: cuda-bindings<14,>=13.0.3 in /usr/local/lib/python3.12/site-packages (from torch<2.12.0,>=2.7->lerobot[training]) (13.2.0)
# Requirement already satisfied: nvidia-cudnn-cu13==9.19.0.56 in /usr/local/lib/python3.12/site-packages (from torch<2.12.0,>=2.7->lerobot[training]) (9.19.0.56)
# Requirement already satisfied: nvidia-cusparselt-cu13==0.8.0 in /usr/local/lib/python3.12/site-packages (from torch<2.12.0,>=2.7->lerobot[training]) (0.8.0)
# Requirement already satisfied: nvidia-nccl-cu13==2.28.9 in /usr/local/lib/python3.12/site-packages (from torch<2.12.0,>=2.7->lerobot[training]) (2.28.9)
# Requirement already satisfied: nvidia-nvshmem-cu13==3.4.5 in /usr/local/lib/python3.12/site-packages (from torch<2.12.0,>=2.7->lerobot[training]) (3.4.5)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/site-packages (from torch<2.12.0,>=2.7->lerobot[training]) (3.6.0)
# Requirement already satisfied: nvidia-cublas==13.1.0.3.* in /usr/local/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch<2.12.0,>=2.7->lerobot[training]) (13.1.0.3)
# Requirement already satisfied: nvidia-cuda-runtime==13.0.96.* in /usr/local/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch<2.12.0,>=2.7->lerobot[training]) (13.0.96)
# Requirement already satisfied: nvidia-cufft==12.0.0.61.* in /usr/local/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch<2.12.0,>=2.7->lerobot[training]) (12.0.0.61)
# Requirement already satisfied: nvidia-cufile==1.15.1.6.* in /usr/local/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch<2.12.0,>=2.7->lerobot[training]) (1.15.1.6)
# Requirement already satisfied: nvidia-cuda-cupti==13.0.85.* in /usr/local/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch<2.12.0,>=2.7->lerobot[training]) (13.0.85)
# Requirement already satisfied: nvidia-curand==10.4.0.35.* in /usr/local/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch<2.12.0,>=2.7->lerobot[training]) (10.4.0.35)
# Requirement already satisfied: nvidia-cusolver==12.0.4.66.* in /usr/local/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch<2.12.0,>=2.7->lerobot[training]) (12.0.4.66)
# Requirement already satisfied: nvidia-cusparse==12.6.3.3.* in /usr/local/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch<2.12.0,>=2.7->lerobot[training]) (12.6.3.3)
# Requirement already satisfied: nvidia-nvjitlink==13.0.88.* in /usr/local/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch<2.12.0,>=2.7->lerobot[training]) (13.0.88)
# Requirement already satisfied: nvidia-cuda-nvrtc==13.0.88.* in /usr/local/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch<2.12.0,>=2.7->lerobot[training]) (13.0.88)
# Requirement already satisfied: nvidia-nvtx==13.0.85.* in /usr/local/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch<2.12.0,>=2.7->lerobot[training]) (13.0.85)
# Requirement already satisfied: click>=8.0.1 in /usr/local/lib/python3.12/site-packages (from wandb<0.25.0,>=0.24.0->lerobot[training]) (8.4.0)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /usr/local/lib/python3.12/site-packages (from wandb<0.25.0,>=0.24.0->lerobot[training]) (3.1.50)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.12/site-packages (from wandb<0.25.0,>=0.24.0->lerobot[training]) (4.3.6)
# Requirement already satisfied: protobuf!=4.21.0,!=5.28.0,<7,>=3.19.0 in /usr/local/lib/python3.12/site-packages (from wandb<0.25.0,>=0.24.0->lerobot[training]) (6.33.6)
# Requirement already satisfied: pydantic<3 in /usr/local/lib/python3.12/site-packages (from wandb<0.25.0,>=0.24.0->lerobot[training]) (2.13.4)
# Requirement already satisfied: sentry-sdk>=2.0.0 in /usr/local/lib/python3.12/site-packages (from wandb<0.25.0,>=0.24.0->lerobot[training]) (2.60.0)
# Requirement already satisfied: datasets<5.0.0,>=4.7.0 in /usr/local/lib/python3.12/site-packages (from lerobot[training]) (4.8.5)
# Requirement already satisfied: pandas<3.0.0,>=2.0.0 in /usr/local/lib/python3.12/site-packages (from lerobot[training]) (2.3.3)
# Requirement already satisfied: pyarrow<30.0.0,>=21.0.0 in /usr/local/lib/python3.12/site-packages (from lerobot[training]) (24.0.0)
# Requirement already satisfied: torchcodec<0.12.0,>=0.3.0 in /usr/local/lib/python3.12/site-packages (from lerobot[training]) (0.11.1)
# Requirement already satisfied: jsonlines<5.0.0,>=4.0.0 in /usr/local/lib/python3.12/site-packages (from lerobot[training]) (4.0.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/site-packages (from cuda-bindings<14,>=13.0.3->torch<2.12.0,>=2.7->lerobot[training]) (1.5.4)
# Requirement already satisfied: dill<0.4.2,>=0.3.0 in /usr/local/lib/python3.12/site-packages (from datasets<5.0.0,>=4.7.0->lerobot[training]) (0.4.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/site-packages (from datasets<5.0.0,>=4.7.0->lerobot[training]) (3.7.0)
# Requirement already satisfied: multiprocess<0.70.20 in /usr/local/lib/python3.12/site-packages (from datasets<5.0.0,>=4.7.0->lerobot[training]) (0.70.19)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.12/site-packages (from gitpython!=3.1.29,>=1.0.0->wandb<0.25.0,>=0.24.0->lerobot[training]) (4.0.12)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0.0,>=1.0.0->lerobot[training]) (4.13.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0.0,>=1.0.0->lerobot[training]) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0.0,>=1.0.0->lerobot[training]) (0.16.0)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.12/site-packages (from jsonlines<5.0.0,>=4.0.0->lerobot[training]) (26.1.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/site-packages (from pandas<3.0.0,>=2.0.0->lerobot[training]) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/site-packages (from pandas<3.0.0,>=2.0.0->lerobot[training]) (2026.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/site-packages (from pandas<3.0.0,>=2.0.0->lerobot[training]) (2026.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/site-packages (from pydantic<3->wandb<0.25.0,>=0.24.0->lerobot[training]) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /usr/local/lib/python3.12/site-packages (from pydantic<3->wandb<0.25.0,>=0.24.0->lerobot[training]) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/site-packages (from pydantic<3->wandb<0.25.0,>=0.24.0->lerobot[training]) (0.4.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/site-packages (from sympy>=1.13.3->torch<2.12.0,>=2.7->lerobot[training]) (1.3.0)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/site-packages (from typer>=0.20.0->huggingface-hub<2.0.0,>=1.0.0->lerobot[training]) (1.5.4)
# Requirement already satisfied: rich>=13.8.0 in /usr/local/lib/python3.12/site-packages (from typer>=0.20.0->huggingface-hub<2.0.0,>=1.0.0->lerobot[training]) (15.0.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/site-packages (from typer>=0.20.0->huggingface-hub<2.0.0,>=1.0.0->lerobot[training]) (0.0.4)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.12/site-packages (from typing-inspect~=0.9.0->draccus==0.10.0->lerobot[training]) (1.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/site-packages (from jinja2->torch<2.12.0,>=2.7->lerobot[training]) (3.0.3)
# Requirement already satisfied: av<16.0.0,>=15.0.0 in /usr/local/lib/python3.12/site-packages (from lerobot[training]) (15.1.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/site-packages (from fsspec[http]<=2026.2.0,>=2023.1.0->datasets<5.0.0,>=4.7.0->lerobot[training]) (3.13.5)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.12/site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb<0.25.0,>=0.24.0->lerobot[training]) (5.0.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas<3.0.0,>=2.0.0->lerobot[training]) (1.17.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/site-packages (from rich>=13.8.0->typer>=0.20.0->huggingface-hub<2.0.0,>=1.0.0->lerobot[training]) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/site-packages (from rich>=13.8.0->typer>=0.20.0->huggingface-hub<2.0.0,>=1.0.0->lerobot[training]) (2.20.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets<5.0.0,>=4.7.0->lerobot[training]) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets<5.0.0,>=4.7.0->lerobot[training]) (1.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets<5.0.0,>=4.7.0->lerobot[training]) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets<5.0.0,>=4.7.0->lerobot[training]) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets<5.0.0,>=4.7.0->lerobot[training]) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets<5.0.0,>=4.7.0->lerobot[training]) (1.24.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer>=0.20.0->huggingface-hub<2.0.0,>=1.0.0->lerobot[training]) (0.1.2)
# Requirement already satisfied: lerobot[dataset] in /usr/local/lib/python3.12/site-packages (0.5.2)
# Requirement already satisfied: torch<2.12.0,>=2.7 in /usr/local/lib/python3.12/site-packages (from lerobot[dataset]) (2.11.0)
# Requirement already satisfied: torchvision<0.27.0,>=0.22.0 in /usr/local/lib/python3.12/site-packages (from lerobot[dataset]) (0.26.0)
# Requirement already satisfied: numpy<2.3.0,>=2.0.0 in /usr/local/lib/python3.12/site-packages (from lerobot[dataset]) (2.2.6)
# Requirement already satisfied: opencv-python-headless<4.14.0,>=4.9.0 in /usr/local/lib/python3.12/site-packages (from lerobot[dataset]) (4.13.0.92)
# Requirement already satisfied: Pillow<13.0.0,>=10.0.0 in /usr/local/lib/python3.12/site-packages (from lerobot[dataset]) (12.2.0)
# Requirement already satisfied: einops<0.9.0,>=0.8.0 in /usr/local/lib/python3.12/site-packages (from lerobot[dataset]) (0.8.2)
# Requirement already satisfied: draccus==0.10.0 in /usr/local/lib/python3.12/site-packages (from lerobot[dataset]) (0.10.0)
# Requirement already satisfied: huggingface-hub<2.0.0,>=1.0.0 in /usr/local/lib/python3.12/site-packages (from lerobot[dataset]) (1.15.0)
# Requirement already satisfied: requests<3.0.0,>=2.32.0 in /usr/local/lib/python3.12/site-packages (from lerobot[dataset]) (2.32.3)
# Requirement already satisfied: gymnasium<2.0.0,>=1.1.1 in /usr/local/lib/python3.12/site-packages (from lerobot[dataset]) (1.3.0)
# Requirement already satisfied: safetensors<1.0.0,>=0.4.3 in /usr/local/lib/python3.12/site-packages (from lerobot[dataset]) (0.7.0)
# Requirement already satisfied: packaging<26.0,>=24.2 in /usr/local/lib/python3.12/site-packages (from lerobot[dataset]) (24.2)
# Requirement already satisfied: termcolor<4.0.0,>=2.4.0 in /usr/local/lib/python3.12/site-packages (from lerobot[dataset]) (3.3.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.0 in /usr/local/lib/python3.12/site-packages (from lerobot[dataset]) (4.67.1)
# Requirement already satisfied: cmake<4.2.0,>=3.29.0.1 in /usr/local/lib/python3.12/site-packages (from lerobot[dataset]) (4.1.3)
# Requirement already satisfied: setuptools<81.0.0,>=71.0.0 in /usr/local/lib/python3.12/site-packages (from lerobot[dataset]) (80.10.2)
# Requirement already satisfied: datasets<5.0.0,>=4.7.0 in /usr/local/lib/python3.12/site-packages (from lerobot[dataset]) (4.8.5)
# Requirement already satisfied: pandas<3.0.0,>=2.0.0 in /usr/local/lib/python3.12/site-packages (from lerobot[dataset]) (2.3.3)
# Requirement already satisfied: pyarrow<30.0.0,>=21.0.0 in /usr/local/lib/python3.12/site-packages (from lerobot[dataset]) (24.0.0)
# Requirement already satisfied: torchcodec<0.12.0,>=0.3.0 in /usr/local/lib/python3.12/site-packages (from lerobot[dataset]) (0.11.1)
# Requirement already satisfied: jsonlines<5.0.0,>=4.0.0 in /usr/local/lib/python3.12/site-packages (from lerobot[dataset]) (4.0.0)
# Requirement already satisfied: mergedeep~=1.3 in /usr/local/lib/python3.12/site-packages (from draccus==0.10.0->lerobot[dataset]) (1.3.4)
# Requirement already satisfied: pyyaml~=6.0 in /usr/local/lib/python3.12/site-packages (from draccus==0.10.0->lerobot[dataset]) (6.0.3)
# Requirement already satisfied: pyyaml-include~=1.4 in /usr/local/lib/python3.12/site-packages (from draccus==0.10.0->lerobot[dataset]) (1.4.1)
# Requirement already satisfied: toml~=0.10 in /usr/local/lib/python3.12/site-packages (from draccus==0.10.0->lerobot[dataset]) (0.10.2)
# Requirement already satisfied: typing-inspect~=0.9.0 in /usr/local/lib/python3.12/site-packages (from draccus==0.10.0->lerobot[dataset]) (0.9.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/site-packages (from datasets<5.0.0,>=4.7.0->lerobot[dataset]) (3.29.0)
# Requirement already satisfied: dill<0.4.2,>=0.3.0 in /usr/local/lib/python3.12/site-packages (from datasets<5.0.0,>=4.7.0->lerobot[dataset]) (0.4.1)
# Requirement already satisfied: httpx<1.0.0 in /usr/local/lib/python3.12/site-packages (from datasets<5.0.0,>=4.7.0->lerobot[dataset]) (0.28.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/site-packages (from datasets<5.0.0,>=4.7.0->lerobot[dataset]) (3.7.0)
# Requirement already satisfied: multiprocess<0.70.20 in /usr/local/lib/python3.12/site-packages (from datasets<5.0.0,>=4.7.0->lerobot[dataset]) (0.70.19)
# Requirement already satisfied: fsspec<=2026.2.0,>=2023.1.0 in /usr/local/lib/python3.12/site-packages (from fsspec[http]<=2026.2.0,>=2023.1.0->datasets<5.0.0,>=4.7.0->lerobot[dataset]) (2026.2.0)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.12/site-packages (from gymnasium<2.0.0,>=1.1.1->lerobot[dataset]) (3.1.2)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.12/site-packages (from gymnasium<2.0.0,>=1.1.1->lerobot[dataset]) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.12/site-packages (from gymnasium<2.0.0,>=1.1.1->lerobot[dataset]) (0.0.6)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in /usr/local/lib/python3.12/site-packages (from huggingface-hub<2.0.0,>=1.0.0->lerobot[dataset]) (1.5.0)
# Requirement already satisfied: typer>=0.20.0 in /usr/local/lib/python3.12/site-packages (from huggingface-hub<2.0.0,>=1.0.0->lerobot[dataset]) (0.25.1)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.12/site-packages (from jsonlines<5.0.0,>=4.0.0->lerobot[dataset]) (26.1.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/site-packages (from pandas<3.0.0,>=2.0.0->lerobot[dataset]) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/site-packages (from pandas<3.0.0,>=2.0.0->lerobot[dataset]) (2026.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/site-packages (from pandas<3.0.0,>=2.0.0->lerobot[dataset]) (2026.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/site-packages (from requests<3.0.0,>=2.32.0->lerobot[dataset]) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/site-packages (from requests<3.0.0,>=2.32.0->lerobot[dataset]) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/site-packages (from requests<3.0.0,>=2.32.0->lerobot[dataset]) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/site-packages (from requests<3.0.0,>=2.32.0->lerobot[dataset]) (2026.4.22)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/site-packages (from torch<2.12.0,>=2.7->lerobot[dataset]) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/site-packages (from torch<2.12.0,>=2.7->lerobot[dataset]) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/site-packages (from torch<2.12.0,>=2.7->lerobot[dataset]) (3.1.6)
# Requirement already satisfied: cuda-toolkit==13.0.2 in /usr/local/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch<2.12.0,>=2.7->lerobot[dataset]) (13.0.2)
# Requirement already satisfied: cuda-bindings<14,>=13.0.3 in /usr/local/lib/python3.12/site-packages (from torch<2.12.0,>=2.7->lerobot[dataset]) (13.2.0)
# Requirement already satisfied: nvidia-cudnn-cu13==9.19.0.56 in /usr/local/lib/python3.12/site-packages (from torch<2.12.0,>=2.7->lerobot[dataset]) (9.19.0.56)
# Requirement already satisfied: nvidia-cusparselt-cu13==0.8.0 in /usr/local/lib/python3.12/site-packages (from torch<2.12.0,>=2.7->lerobot[dataset]) (0.8.0)
# Requirement already satisfied: nvidia-nccl-cu13==2.28.9 in /usr/local/lib/python3.12/site-packages (from torch<2.12.0,>=2.7->lerobot[dataset]) (2.28.9)
# Requirement already satisfied: nvidia-nvshmem-cu13==3.4.5 in /usr/local/lib/python3.12/site-packages (from torch<2.12.0,>=2.7->lerobot[dataset]) (3.4.5)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/site-packages (from torch<2.12.0,>=2.7->lerobot[dataset]) (3.6.0)
# Requirement already satisfied: nvidia-cublas==13.1.0.3.* in /usr/local/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch<2.12.0,>=2.7->lerobot[dataset]) (13.1.0.3)
# Requirement already satisfied: nvidia-cuda-runtime==13.0.96.* in /usr/local/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch<2.12.0,>=2.7->lerobot[dataset]) (13.0.96)
# Requirement already satisfied: nvidia-cufft==12.0.0.61.* in /usr/local/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch<2.12.0,>=2.7->lerobot[dataset]) (12.0.0.61)
# Requirement already satisfied: nvidia-cufile==1.15.1.6.* in /usr/local/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch<2.12.0,>=2.7->lerobot[dataset]) (1.15.1.6)
# Requirement already satisfied: nvidia-cuda-cupti==13.0.85.* in /usr/local/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch<2.12.0,>=2.7->lerobot[dataset]) (13.0.85)
# Requirement already satisfied: nvidia-curand==10.4.0.35.* in /usr/local/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch<2.12.0,>=2.7->lerobot[dataset]) (10.4.0.35)
# Requirement already satisfied: nvidia-cusolver==12.0.4.66.* in /usr/local/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch<2.12.0,>=2.7->lerobot[dataset]) (12.0.4.66)
# Requirement already satisfied: nvidia-cusparse==12.6.3.3.* in /usr/local/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch<2.12.0,>=2.7->lerobot[dataset]) (12.6.3.3)
# Requirement already satisfied: nvidia-nvjitlink==13.0.88.* in /usr/local/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch<2.12.0,>=2.7->lerobot[dataset]) (13.0.88)
# Requirement already satisfied: nvidia-cuda-nvrtc==13.0.88.* in /usr/local/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch<2.12.0,>=2.7->lerobot[dataset]) (13.0.88)
# Requirement already satisfied: nvidia-nvtx==13.0.85.* in /usr/local/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch<2.12.0,>=2.7->lerobot[dataset]) (13.0.85)
# Requirement already satisfied: av<16.0.0,>=15.0.0 in /usr/local/lib/python3.12/site-packages (from lerobot[dataset]) (15.1.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/site-packages (from cuda-bindings<14,>=13.0.3->torch<2.12.0,>=2.7->lerobot[dataset]) (1.5.4)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.12/site-packages (from fsspec[http]<=2026.2.0,>=2023.1.0->datasets<5.0.0,>=4.7.0->lerobot[dataset]) (3.13.5)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/site-packages (from httpx<1.0.0->datasets<5.0.0,>=4.7.0->lerobot[dataset]) (4.13.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/site-packages (from httpx<1.0.0->datasets<5.0.0,>=4.7.0->lerobot[dataset]) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/site-packages (from httpcore==1.*->httpx<1.0.0->datasets<5.0.0,>=4.7.0->lerobot[dataset]) (0.16.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas<3.0.0,>=2.0.0->lerobot[dataset]) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/site-packages (from sympy>=1.13.3->torch<2.12.0,>=2.7->lerobot[dataset]) (1.3.0)
# Requirement already satisfied: click>=8.2.1 in /usr/local/lib/python3.12/site-packages (from typer>=0.20.0->huggingface-hub<2.0.0,>=1.0.0->lerobot[dataset]) (8.4.0)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/site-packages (from typer>=0.20.0->huggingface-hub<2.0.0,>=1.0.0->lerobot[dataset]) (1.5.4)
# Requirement already satisfied: rich>=13.8.0 in /usr/local/lib/python3.12/site-packages (from typer>=0.20.0->huggingface-hub<2.0.0,>=1.0.0->lerobot[dataset]) (15.0.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/site-packages (from typer>=0.20.0->huggingface-hub<2.0.0,>=1.0.0->lerobot[dataset]) (0.0.4)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.12/site-packages (from typing-inspect~=0.9.0->draccus==0.10.0->lerobot[dataset]) (1.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/site-packages (from jinja2->torch<2.12.0,>=2.7->lerobot[dataset]) (3.0.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets<5.0.0,>=4.7.0->lerobot[dataset]) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets<5.0.0,>=4.7.0->lerobot[dataset]) (1.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets<5.0.0,>=4.7.0->lerobot[dataset]) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets<5.0.0,>=4.7.0->lerobot[dataset]) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets<5.0.0,>=4.7.0->lerobot[dataset]) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets<5.0.0,>=4.7.0->lerobot[dataset]) (1.24.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/site-packages (from rich>=13.8.0->typer>=0.20.0->huggingface-hub<2.0.0,>=1.0.0->lerobot[dataset]) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/site-packages (from rich>=13.8.0->typer>=0.20.0->huggingface-hub<2.0.0,>=1.0.0->lerobot[dataset]) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer>=0.20.0->huggingface-hub<2.0.0,>=1.0.0->lerobot[dataset]) (0.1.2)

# %% [markdown]
# ## Weights & Biases login
# This cell logs you into Weights & Biases (wandb) to enable experiment tracking and logging.

# %%
# !wandb login
# Out:
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from /root/.netrc.
# wandb: Currently logged in as: qianli-ma622 (qianli-ma622-personal) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin

# %% [markdown]
# ## Install SmolVLA dependencies

# %%
# !cd lerobot && pip install -e ".[smolvla]"
# Out:
# Obtaining file:///content/lerobot
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# Requirement already satisfied: torch<2.12.0,>=2.7 in /usr/local/lib/python3.12/site-packages (from lerobot==0.5.2) (2.11.0)
# Requirement already satisfied: torchvision<0.27.0,>=0.22.0 in /usr/local/lib/python3.12/site-packages (from lerobot==0.5.2) (0.26.0)
# Requirement already satisfied: numpy<2.3.0,>=2.0.0 in /usr/local/lib/python3.12/site-packages (from lerobot==0.5.2) (2.2.6)
# Requirement already satisfied: opencv-python-headless<4.14.0,>=4.9.0 in /usr/local/lib/python3.12/site-packages (from lerobot==0.5.2) (4.13.0.92)
# Requirement already satisfied: Pillow<13.0.0,>=10.0.0 in /usr/local/lib/python3.12/site-packages (from lerobot==0.5.2) (12.2.0)
# Requirement already satisfied: einops<0.9.0,>=0.8.0 in /usr/local/lib/python3.12/site-packages (from lerobot==0.5.2) (0.8.2)
# Requirement already satisfied: draccus==0.10.0 in /usr/local/lib/python3.12/site-packages (from lerobot==0.5.2) (0.10.0)
# Requirement already satisfied: huggingface-hub<2.0.0,>=1.0.0 in /usr/local/lib/python3.12/site-packages (from lerobot==0.5.2) (1.15.0)
# Requirement already satisfied: requests<3.0.0,>=2.32.0 in /usr/local/lib/python3.12/site-packages (from lerobot==0.5.2) (2.32.3)
# Requirement already satisfied: gymnasium<2.0.0,>=1.1.1 in /usr/local/lib/python3.12/site-packages (from lerobot==0.5.2) (1.3.0)
# Requirement already satisfied: safetensors<1.0.0,>=0.4.3 in /usr/local/lib/python3.12/site-packages (from lerobot==0.5.2) (0.7.0)
# Requirement already satisfied: packaging<26.0,>=24.2 in /usr/local/lib/python3.12/site-packages (from lerobot==0.5.2) (24.2)
# Requirement already satisfied: termcolor<4.0.0,>=2.4.0 in /usr/local/lib/python3.12/site-packages (from lerobot==0.5.2) (3.3.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.66.0 in /usr/local/lib/python3.12/site-packages (from lerobot==0.5.2) (4.67.1)
# Requirement already satisfied: cmake<4.2.0,>=3.29.0.1 in /usr/local/lib/python3.12/site-packages (from lerobot==0.5.2) (4.1.3)
# Requirement already satisfied: setuptools<81.0.0,>=71.0.0 in /usr/local/lib/python3.12/site-packages (from lerobot==0.5.2) (80.10.2)
# Requirement already satisfied: mergedeep~=1.3 in /usr/local/lib/python3.12/site-packages (from draccus==0.10.0->lerobot==0.5.2) (1.3.4)
# Requirement already satisfied: pyyaml~=6.0 in /usr/local/lib/python3.12/site-packages (from draccus==0.10.0->lerobot==0.5.2) (6.0.3)
# Requirement already satisfied: pyyaml-include~=1.4 in /usr/local/lib/python3.12/site-packages (from draccus==0.10.0->lerobot==0.5.2) (1.4.1)
# Requirement already satisfied: toml~=0.10 in /usr/local/lib/python3.12/site-packages (from draccus==0.10.0->lerobot==0.5.2) (0.10.2)
# Requirement already satisfied: typing-inspect~=0.9.0 in /usr/local/lib/python3.12/site-packages (from draccus==0.10.0->lerobot==0.5.2) (0.9.0)
# Collecting num2words<0.6.0,>=0.5.14 (from lerobot==0.5.2)
#   Downloading num2words-0.5.14-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: accelerate<2.0.0,>=1.7.0 in /usr/local/lib/python3.12/site-packages (from lerobot==0.5.2) (1.13.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/site-packages (from accelerate<2.0.0,>=1.7.0->lerobot==0.5.2) (7.2.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.12/site-packages (from gymnasium<2.0.0,>=1.1.1->lerobot==0.5.2) (3.1.2)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.12/site-packages (from gymnasium<2.0.0,>=1.1.1->lerobot==0.5.2) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.12/site-packages (from gymnasium<2.0.0,>=1.1.1->lerobot==0.5.2) (0.0.6)
# Requirement already satisfied: filelock>=3.10.0 in /usr/local/lib/python3.12/site-packages (from huggingface-hub<2.0.0,>=1.0.0->lerobot==0.5.2) (3.29.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/site-packages (from huggingface-hub<2.0.0,>=1.0.0->lerobot==0.5.2) (2026.2.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in /usr/local/lib/python3.12/site-packages (from huggingface-hub<2.0.0,>=1.0.0->lerobot==0.5.2) (1.5.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/site-packages (from huggingface-hub<2.0.0,>=1.0.0->lerobot==0.5.2) (0.28.1)
# Requirement already satisfied: typer>=0.20.0 in /usr/local/lib/python3.12/site-packages (from huggingface-hub<2.0.0,>=1.0.0->lerobot==0.5.2) (0.25.1)
# Collecting docopt>=0.6.2 (from num2words<0.6.0,>=0.5.14->lerobot==0.5.2)
#   Downloading docopt-0.6.2.tar.gz (25 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/site-packages (from requests<3.0.0,>=2.32.0->lerobot==0.5.2) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/site-packages (from requests<3.0.0,>=2.32.0->lerobot==0.5.2) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/site-packages (from requests<3.0.0,>=2.32.0->lerobot==0.5.2) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/site-packages (from requests<3.0.0,>=2.32.0->lerobot==0.5.2) (2026.4.22)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/site-packages (from torch<2.12.0,>=2.7->lerobot==0.5.2) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/site-packages (from torch<2.12.0,>=2.7->lerobot==0.5.2) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/site-packages (from torch<2.12.0,>=2.7->lerobot==0.5.2) (3.1.6)
# Requirement already satisfied: cuda-toolkit==13.0.2 in /usr/local/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch<2.12.0,>=2.7->lerobot==0.5.2) (13.0.2)
# Requirement already satisfied: cuda-bindings<14,>=13.0.3 in /usr/local/lib/python3.12/site-packages (from torch<2.12.0,>=2.7->lerobot==0.5.2) (13.2.0)
# Requirement already satisfied: nvidia-cudnn-cu13==9.19.0.56 in /usr/local/lib/python3.12/site-packages (from torch<2.12.0,>=2.7->lerobot==0.5.2) (9.19.0.56)
# Requirement already satisfied: nvidia-cusparselt-cu13==0.8.0 in /usr/local/lib/python3.12/site-packages (from torch<2.12.0,>=2.7->lerobot==0.5.2) (0.8.0)
# Requirement already satisfied: nvidia-nccl-cu13==2.28.9 in /usr/local/lib/python3.12/site-packages (from torch<2.12.0,>=2.7->lerobot==0.5.2) (2.28.9)
# Requirement already satisfied: nvidia-nvshmem-cu13==3.4.5 in /usr/local/lib/python3.12/site-packages (from torch<2.12.0,>=2.7->lerobot==0.5.2) (3.4.5)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/site-packages (from torch<2.12.0,>=2.7->lerobot==0.5.2) (3.6.0)
# Requirement already satisfied: nvidia-cublas==13.1.0.3.* in /usr/local/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch<2.12.0,>=2.7->lerobot==0.5.2) (13.1.0.3)
# Requirement already satisfied: nvidia-cuda-runtime==13.0.96.* in /usr/local/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch<2.12.0,>=2.7->lerobot==0.5.2) (13.0.96)
# Requirement already satisfied: nvidia-cufft==12.0.0.61.* in /usr/local/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch<2.12.0,>=2.7->lerobot==0.5.2) (12.0.0.61)
# Requirement already satisfied: nvidia-cufile==1.15.1.6.* in /usr/local/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch<2.12.0,>=2.7->lerobot==0.5.2) (1.15.1.6)
# Requirement already satisfied: nvidia-cuda-cupti==13.0.85.* in /usr/local/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch<2.12.0,>=2.7->lerobot==0.5.2) (13.0.85)
# Requirement already satisfied: nvidia-curand==10.4.0.35.* in /usr/local/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch<2.12.0,>=2.7->lerobot==0.5.2) (10.4.0.35)
# Requirement already satisfied: nvidia-cusolver==12.0.4.66.* in /usr/local/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch<2.12.0,>=2.7->lerobot==0.5.2) (12.0.4.66)
# Requirement already satisfied: nvidia-cusparse==12.6.3.3.* in /usr/local/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch<2.12.0,>=2.7->lerobot==0.5.2) (12.6.3.3)
# Requirement already satisfied: nvidia-nvjitlink==13.0.88.* in /usr/local/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch<2.12.0,>=2.7->lerobot==0.5.2) (13.0.88)
# Requirement already satisfied: nvidia-cuda-nvrtc==13.0.88.* in /usr/local/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch<2.12.0,>=2.7->lerobot==0.5.2) (13.0.88)
# Requirement already satisfied: nvidia-nvtx==13.0.85.* in /usr/local/lib/python3.12/site-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==13.0.2; platform_system == "Linux"->torch<2.12.0,>=2.7->lerobot==0.5.2) (13.0.85)
# Collecting transformers<5.6.0,>=5.4.0 (from lerobot==0.5.2)
#   Downloading transformers-5.5.4-py3-none-any.whl.metadata (32 kB)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/site-packages (from cuda-bindings<14,>=13.0.3->torch<2.12.0,>=2.7->lerobot==0.5.2) (1.5.4)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0.0,>=1.0.0->lerobot==0.5.2) (4.13.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0.0,>=1.0.0->lerobot==0.5.2) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0.0,>=1.0.0->lerobot==0.5.2) (0.16.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/site-packages (from sympy>=1.13.3->torch<2.12.0,>=2.7->lerobot==0.5.2) (1.3.0)
# Collecting regex>=2025.10.22 (from transformers<5.6.0,>=5.4.0->lerobot==0.5.2)
#   Downloading regex-2026.5.9-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (40 kB)
# Collecting tokenizers<=0.23.0,>=0.22.0 (from transformers<5.6.0,>=5.4.0->lerobot==0.5.2)
#   Downloading tokenizers-0.22.2-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.3 kB)
# Requirement already satisfied: click>=8.2.1 in /usr/local/lib/python3.12/site-packages (from typer>=0.20.0->huggingface-hub<2.0.0,>=1.0.0->lerobot==0.5.2) (8.4.0)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/site-packages (from typer>=0.20.0->huggingface-hub<2.0.0,>=1.0.0->lerobot==0.5.2) (1.5.4)
# Requirement already satisfied: rich>=13.8.0 in /usr/local/lib/python3.12/site-packages (from typer>=0.20.0->huggingface-hub<2.0.0,>=1.0.0->lerobot==0.5.2) (15.0.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/site-packages (from typer>=0.20.0->huggingface-hub<2.0.0,>=1.0.0->lerobot==0.5.2) (0.0.4)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.12/site-packages (from typing-inspect~=0.9.0->draccus==0.10.0->lerobot==0.5.2) (1.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/site-packages (from jinja2->torch<2.12.0,>=2.7->lerobot==0.5.2) (3.0.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/site-packages (from rich>=13.8.0->typer>=0.20.0->huggingface-hub<2.0.0,>=1.0.0->lerobot==0.5.2) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/site-packages (from rich>=13.8.0->typer>=0.20.0->huggingface-hub<2.0.0,>=1.0.0->lerobot==0.5.2) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer>=0.20.0->huggingface-hub<2.0.0,>=1.0.0->lerobot==0.5.2) (0.1.2)
# Downloading num2words-0.5.14-py3-none-any.whl (163 kB)
# Downloading transformers-5.5.4-py3-none-any.whl (10.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 116.9 MB/s eta 0:00:00
# Downloading regex-2026.5.9-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (801 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 801.2/801.2 kB 73.4 MB/s eta 0:00:00
# Downloading tokenizers-0.22.2-cp39-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 179.1 MB/s eta 0:00:00
# Building wheels for collected packages: lerobot, docopt
#   Building editable for lerobot (pyproject.toml) ... done
#   Created wheel for lerobot: filename=lerobot-0.5.2-0.editable-py3-none-any.whl size=13549 sha256=334d0ff392453579c703debcfec12f0bd395a66d65b1039d1405a1ba0317e39e
#   Stored in directory: /tmp/pip-ephem-wheel-cache-m2cbj9n2/wheels/09/b4/fe/75732b1d640db96ba1f856f2b7328b232a03b696a39cb59686
#   Building wheel for docopt (setup.py) ... done
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13781 sha256=a89ba1158af757b1d0db7f2a5f1116430aa0f5f992e8746f9106224e37a8f445
#   Stored in directory: /root/.cache/pip/wheels/1a/bf/a1/4cee4f7678c68c5875ca89eaccf460593539805c3906722228
# Successfully built lerobot docopt
# Installing collected packages: docopt, regex, num2words, tokenizers, transformers, lerobot
#   Attempting uninstall: lerobot
#     Found existing installation: lerobot 0.5.2
#     Uninstalling lerobot-0.5.2:
#       Successfully uninstalled lerobot-0.5.2
# Successfully installed docopt-0.6.2 lerobot-0.5.2 num2words-0.5.14 regex-2026.5.9 tokenizers-0.22.2 transformers-5.5.4

# %% [markdown]
# ## Start training SmolVLA with LeRobot
#
# This cell runs the `train.py` script from the `lerobot` library to train a robot control policy.
#
# Make sure to adjust the following arguments to your setup:
#
# 1. `--dataset.repo_id=YOUR_HF_USERNAME/YOUR_DATASET`:
#    Replace this with the Hugging Face Hub repo ID where your dataset is stored, e.g., `pepijn223/il_gym0`.
#
# 2. `--batch_size=64`: means the model processes 64 training samples in parallel before doing one gradient update. Reduce this number if you have a GPU with low memory.
#
# 3. `--output_dir=outputs/train/...`:
#    Directory where training logs and model checkpoints will be saved.
#
# 4. `--job_name=...`:
#    A name for this training job, used for logging and Weights & Biases.
#
# 5. `--policy.device=cuda`:
#    Use `cuda` if training on an NVIDIA GPU. Use `mps` for Apple Silicon, or `cpu` if no GPU is available.
#
# 6. `--wandb.enable=true`:
#    Enables Weights & Biases for visualizing training progress. You must be logged in via `wandb login` before running this.

# %%
# !cd lerobot && python lerobot/scripts/train.py \
  --policy.path=lerobot/smolvla_base \
  --dataset.repo_id=${HF_USER}/mydataset \
  --batch_size=64 \
  --steps=20000 \
  --output_dir=outputs/train/my_smolvla \
  --job_name=my_smolvla_training \
  --policy.device=cuda \
  --wandb.enable=true

# %% [markdown]
# ## Login into Hugging Face Hub
# Now after training is done login into the Hugging Face hub and upload the last checkpoint

# %%
# !huggingface-cli login

# %%
# !huggingface-cli upload ${HF_USER}/my_smolvla \
  /content/lerobot/outputs/train/my_smolvla/checkpoints/last/pretrained_model
